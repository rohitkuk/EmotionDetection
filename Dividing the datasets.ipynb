# %%
import pandas as pd

# %%
df = pd.read_csv('Dataset\\fer2013.csv')

# %%
dataset_types = ['Training', 'PrivateTest', 'PublicTest']

# %%
for dataset_type in dataset_types:
    temp = df[df["Usage"] == dataset_type]
    temp.to_csv(f'Dataset\\{dataset_type}.csv',index = False)
